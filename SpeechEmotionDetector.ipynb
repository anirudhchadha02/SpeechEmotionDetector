# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
import warnings
from IPython.display import Audio
warnings.filterwarnings('ignore')

# %%
# !pip install librosa-display
# Out:
# ERROR: Could not find a version that satisfies the requirement librosa-display (from versions: none)
# ERROR: No matching distribution found for librosa-display

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('TESS Toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:5]
# Out:
# ['TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
df=pd.DataFrame()
df['speech']=paths
df['labels']=labels

# %%
df['labels'].value_counts()
# Out:
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: labels, dtype: int64

# %%
def create_waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for {} emotion'.format(emotion), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def create_spectrogram(data, sr, emotion):
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for {} emotion'.format(emotion), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')  
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['labels']==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275506e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228361e+00, -5.57365894e-01, -1.83255327e+00,  2.02101514e-01,
#         7.27551103e-01,  1.31773770e+00,  2.88633752e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651056e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722402e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390714e+00,
#         4.86896276e+00,  9.31392384e+00,  2.08915019e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600896, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550478, -0.21709539, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['labels']])
y = y.toarray()
y.shape
# Out:
# (2800, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305,799
# Trainable params: 305,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install keras
# !pip install tensorflow
# Out:
# Requirement already satisfied: keras in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (2.13.1)
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Downloading tensorflow_intel-2.12.0-cp310-cp310-win_amd64.whl (272.8 MB)
#      -------------------------------------- 272.8/272.8 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ------------------------------------- 440.7/440.7 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.56.0-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 6.0 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
#      ---------------------------------------- 24.4/24.4 MB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: packaging in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB 1.8 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 11.1 MB/s eta 0:00:00
# Collecting jax>=0.3.15
#   Downloading jax-0.4.13.tar.gz (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 6.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Collecting ml-dtypes>=0.1.0
#   Downloading ml_dtypes-0.2.0-cp310-cp310-win_amd64.whl (938 kB)
#      -------------------------------------- 938.6/938.6 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.19.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: urllib3<2.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\anirudh.chadha\appdata\local\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml): started
#   Building wheel for jax (pyproject.toml): finished with status 'done'
#   Created wheel for jax: filename=jax-0.4.13-py3-none-any.whl size=1518835 sha256=5b585b239d6fdbdc269a87f3875604ec91f6d03febbc258bb0ed2962b8319479
#   Stored in directory: c:\users\anirudh.chadha\appdata\local\pip\cache\wheels\4c\a3\e7\ea156aff3754a8f833f1b0c9587dec0bcfc9c551c439c9dcc7
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, opt-einsum, ml-dtypes, keras, grpcio, google-pasta, gast, astunparse, jax, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
# Successfully installed astunparse-1.6.3 flatbuffers-23.5.26 gast-0.4.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.56.0 jax-0.4.13 keras-2.12.0 libclang-16.0.0 ml-dtypes-0.2.0 opt-einsum-3.3.0 tensorboard-2.12.3 tensorboard-data-server-0.7.1 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-intel-2.12.0 tensorflow-io-gcs-filesystem-0.31.0

# %%
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 8s 138ms/step - loss: 1.0801 - accuracy: 0.6192 - val_loss: 1.1197 - val_accuracy: 0.4750
# Epoch 2/50
# 35/35 [==============================] - 5s 137ms/step - loss: 0.3820 - accuracy: 0.8754 - val_loss: 0.3050 - val_accuracy: 0.9071
# Epoch 3/50
# 35/35 [==============================] - 5s 151ms/step - loss: 0.1869 - accuracy: 0.9446 - val_loss: 0.1092 - val_accuracy: 0.9643
# Epoch 4/50
# 35/35 [==============================] - 5s 132ms/step - loss: 0.1562 - accuracy: 0.9487 - val_loss: 0.1116 - val_accuracy: 0.9536
# Epoch 5/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.0948 - accuracy: 0.9696 - val_loss: 0.0711 - val_accuracy: 0.9714
# Epoch 6/50
# 35/35 [==============================] - 4s 121ms/step - loss: 0.1016 - accuracy: 0.9661 - val_loss: 0.0957 - val_accuracy: 0.9607
# Epoch 7/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.
ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 8.6192e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 35/35 [==============================] - 4s 124ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 0.0159 - val_accuracy: 0.9946
# Epoch 31/50
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0026 - val_accuracy: 0.9982
# Epoch 32/50
# 35/35 [==============================] - 4s 124ms/step - loss: 0.0077 - accuracy: 0.9982 - val_loss: 0.0209 - val_accuracy: 0.9893
# Epoch 33/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.3053 - val_accuracy: 0.9321
# Epoch 34/50
# 35/35 [==============================] - 4s 122ms/step - loss: 0.0645 - accuracy: 0.9804 - val_loss: 0.0860 - val_accuracy: 0.9625
# Epoch 35/50
# 35/35 [==============================] - 4s 122ms/step - loss: 0.0346 - accuracy: 0.9871 - val_loss: 0.0196 - val_accuracy: 0.9911
# Epoch 36/50
# 35/35 [==============================] - 4s 125ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.0856 - val_accuracy: 0.9786
# Epoch 37/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 38/50
# 35/35 [==============================] - 4s 128ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 39/50
# 35/35 [==============================] - 4s 121ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/50
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0038 - accuracy: 0.9982 - val_loss: 0.0271 - val_accuracy: 0.9875
# Epoch 41/50
# 35/35 [==============================] - 4s 126ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0126 - val_accuracy: 0.9946
# Epoch 42/50
# 35/35 [==============================] - 4s 121ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0024 - val_accuracy: 0.9982
# Epoch 43/50
# 35/35 [==============================] - 4s 121ms/step - loss: 7.1797e-04 - accuracy: 1.0000 - val_loss: 5.6149e-05 - val_accuracy: 1.0000
# Epoch 44/50
# 35/35 [==============================] - 4s 124ms/step - loss: 6.6329e-04 - accuracy: 1.0000 - val_loss: 3.2761e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 35/35 [==============================] - 4s 123ms/step - loss: 1.9333e-04 - accuracy: 1.0000 - val_loss: 3.7654e-05 - val_accuracy: 1.0000
# Epoch 46/50
# 35/35 [==============================] - 4s 123ms/step - loss: 2.3687e-04 - accuracy: 1.0000 - val_loss: 3.7145e-05 - val_accuracy: 1.0000
# Epoch 47/50
# 35/35 [==============================] - 4s 124ms/step - loss: 2.5486e-04 - accuracy: 1.0000 - val_loss: 2.6608e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 35/35 [==============================] - 4s 122ms/step - loss: 1.7080e-04 - accuracy: 1.0000 - val_loss: 2.2839e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 35/35 [==============================] - 4s 120ms/step - loss: 1.3849e-04 - accuracy: 1.0000 - val_loss: 2.1902e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 35/35 [==============================] - 4s 124ms/step - loss: 1.9642e-04 - accuracy: 1.0000 - val_loss: 2.3976e-05 - val_accuracy: 1.0000

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
